# %%
from linguistics.similarity import Sentence

# %%
from linguistics.document import Document

# %%
doc = Document(text='I like the idea of living in Japan for a month.')

# %%
doc.entities
# Out:
# [Japan (geopolitical_entity), a month (date)]

# %%
doc.entity_graph
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.50.0 (20211204.2007)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="652pt" height="567pt"
#  viewBox="0.00 0.00 652.40 567.40" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(7.2 560.2)">
# <title>G</title>
# <g id="a_graph0"><a xlink:href="https://github.com/idin/abstract" xlink:title="&#10;Powered by Abstract" target="_blank">
# <polygon fill="#fafafa" stroke="transparent" points="-7.2,7.2 -7.2,-560.2 645.2,-560.2 645.2,7.2 -7.2,7.2"/>
# <text text-anchor="middle" x="319" y="-7" font-family="Helvetica,sans-Serif" font-size="10.00" fill="#009acd">Powered by Abstract</text>
# </a>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12) -->
# <g id="node1" class="node">
# <title>(0, &#39;sentence&#39;, 0, 12)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M142,-310C142,-310 12,-310 12,-310 6,-310 0,-304 0,-298 0,-298 0,-286 0,-286 0,-280 6,-274 12,-274 12,-274 142,-274 142,-274 148,-274 154,-280 154,-286 154,-286 154,-298 154,-298 154,-304 148,-310 142,-310"/>
# <text text-anchor="middle" x="77" y="-294.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">I like the idea of living in Japan for a month.</text>
# <text text-anchor="middle" x="77" y="-286.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">(one sentence)</text>
# </g>
# <!-- (0, &#39;token&#39;, 1) -->
# <g id="node3" class="node">
# <title>(0, &#39;token&#39;, 1)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M246.5,-499C246.5,-499 216.5,-499 216.5,-499 210.5,-499 204.5,-493 204.5,-487 204.5,-487 204.5,-475 204.5,-475 204.5,-469 210.5,-463 216.5,-463 216.5,-463 246.5,-463 246.5,-463 252.5,-463 258.5,-469 258.5,-475 258.5,-475 258.5,-487 258.5,-487 258.5,-493 252.5,-499 246.5,-499"/>
# <text text-anchor="middle" x="231.5" y="-483.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">[1] &#39;like&#39;</text>
# <text text-anchor="middle" x="231.5" y="-474.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">verb</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 1) -->
# <g id="edge2" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 1)</title>
# <path fill="none" stroke="#959595" d="M87.53,-310.17C104.83,-341.98 143.92,-408.69 190,-454 193.03,-456.98 196.44,-459.83 199.95,-462.49"/>
# <polygon fill="#959595" stroke="#959595" points="199.04,-463.99 204.11,-465.52 201.1,-461.16 199.04,-463.99"/>
# </g>
# <!-- (0, &#39;token&#39;, 4) -->
# <g id="node6" class="node">
# <title>(0, &#39;token&#39;, 4)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M246.5,-391C246.5,-391 216.5,-391 216.5,-391 210.5,-391 204.5,-385 204.5,-379 204.5,-379 204.5,-367 204.5,-367 204.5,-361 210.5,-355 216.5,-355 216.5,-355 246.5,-355 246.5,-355 252.5,-355 258.5,-361 258.5,-367 258.5,-367 258.5,-379 258.5,-379 258.5,-385 252.5,-391 246.5,-391"/>
# <text text-anchor="middle" x="231.5" y="-375.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">[4] &#39;of&#39;</text>
# <text text-anchor="middle" x="231.5" y="-366.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">adposition</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 4) -->
# <g id="edge4" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 4)</title>
# <path fill="none" stroke="#959595" d="M112.22,-310.18C138.51,-324.14 174.5,-343.25 199.85,-356.72"/>
# <polygon fill="#959595" stroke="#959595" points="199.22,-358.37 204.45,-359.17 200.86,-355.27 199.22,-358.37"/>
# </g>
# <!-- (0, &#39;token&#39;, 5) -->
# <g id="node7" class="node">
# <title>(0, &#39;token&#39;, 5)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M246.5,-337C246.5,-337 216.5,-337 216.5,-337 210.5,-337 204.5,-331 204.5,-325 204.5,-325 204.5,-313 204.5,-313 204.5,-307 210.5,-301 216.5,-301 216.5,-301 246.5,-301 246.5,-301 252.5,-301 258.5,-307 258.5,-313 258.5,-313 258.5,-325 258.5,-325 258.5,-331 252.5,-337 246.5,-337"/>
# <text text-anchor="middle" x="231.5" y="-321.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">[5] &#39;living&#39;</text>
# <text text-anchor="middle" x="231.5" y="-312.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">verb</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 5) -->
# <g id="edge5" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 5)</title>
# <path fill="none" stroke="#959595" d="M154.25,-305.5C170.16,-308.32 186.07,-311.13 199.21,-313.46"/>
# <polygon fill="#959595" stroke="#959595" points="199.06,-315.21 204.28,-314.36 199.67,-311.76 199.06,-315.21"/>
# </g>
# <!-- (0, &#39;token&#39;, 6) -->
# <g id="node8" class="node">
# <title>(0, &#39;token&#39;, 6)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M246.5,-283C246.5,-283 216.5,-283 216.5,-283 210.5,-283 204.5,-277 204.5,-271 204.5,-271 204.5,-259 204.5,-259 204.5,-253 210.5,-247 216.5,-247 216.5,-247 246.5,-247 246.5,-247 252.5,-247 258.5,-253 258.5,-259 258.5,-259 258.5,-271 258.5,-271 258.5,-277 252.5,-283 246.5,-283"/>
# <text text-anchor="middle" x="231.5" y="-267.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">[6] &#39;in&#39;</text>
# <text text-anchor="middle" x="231.5" y="-258.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">adposition</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 6) -->
# <g id="edge6" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 6)</title>
# <path fill="none" stroke="#959595" d="M154.25,-278.5C170.16,-275.68 186.07,-272.87 199.21,-270.54"/>
# <polygon fill="#959595" stroke="#959595" points="199.67,-272.24 204.28,-269.64 199.06,-268.79 199.67,-272.24"/>
# </g>
# <!-- (0, &#39;token&#39;, 8) -->
# <g id="node10" class="node">
# <title>(0, &#39;token&#39;, 8)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M246.5,-175C246.5,-175 216.5,-175 216.5,-175 210.5,-175 204.5,-169 204.5,-163 204.5,-163 204.5,-151 204.5,-151 204.5,-145 210.5,-139 216.5,-139 216.5,-139 246.5,-139 246.5,-139 252.5,-139 258.5,-145 258.5,-151 258.5,-151 258.5,-163 258.5,-163 258.5,-169 252.5,-175 246.5,-175"/>
# <text text-anchor="middle" x="231.5" y="-159.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">[8] &#39;for&#39;</text>
# <text text-anchor="middle" x="231.5" y="-150.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">adposition</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 8) -->
# <g id="edge8" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 8)</title>
# <path fill="none" stroke="#959595" d="M94.94,-273.76C116.13,-251.42 154.01,-212.96 190,-184 193.22,-181.41 196.68,-178.83 200.18,-176.34"/>
# <polygon fill="#959595" stroke="#959595" points="201.2,-177.76 204.3,-173.47 199.2,-174.89 201.2,-177.76"/>
# </g>
# <!-- (0, &#39;token&#39;, 11) -->
# <g id="node13" class="node">
# <title>(0, &#39;token&#39;, 11)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M248.5,-67C248.5,-67 214.5,-67 214.5,-67 208.5,-67 202.5,-61 202.5,-55 202.5,-55 202.5,-43 202.5,-43 202.5,-37 208.5,-31 214.5,-31 214.5,-31 248.5,-31 248.5,-31 254.5,-31 260.5,-37 260.5,-43 260.5,-43 260.5,-55 260.5,-55 260.5,-61 254.5,-67 248.5,-67"/>
# <text text-anchor="middle" x="231.5" y="-51.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">[11] &#39;.&#39;</text>
# <text text-anchor="middle" x="231.5" y="-42.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#000000">punctuation</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 11) -->
# <g id="edge10" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 11)</title>
# <path fill="none" stroke="#959595" d="M83.84,-273.95C97.34,-234.4 133

# %%
doc.syntax_graph
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.50.0 (20211204.2007)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="1059pt" height="192pt"
#  viewBox="0.00 0.00 1059.40 192.40" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(7.2 185.2)">
# <title>G</title>
# <g id="a_graph0"><a xlink:href="https://github.com/idin/abstract" xlink:title="&#10;Powered by Abstract" target="_blank">
# <polygon fill="#fafafa" stroke="transparent" points="-7.2,7.2 -7.2,-185.2 1052.2,-185.2 1052.2,7.2 -7.2,7.2"/>
# <text text-anchor="middle" x="522.5" y="-7" font-family="Helvetica,sans-Serif" font-size="10.00" fill="#009acd">Powered by Abstract</text>
# </a>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12) -->
# <g id="node1" class="node">
# <title>(0, &#39;sentence&#39;, 0, 12)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M142,-124C142,-124 12,-124 12,-124 6,-124 0,-118 0,-112 0,-112 0,-100 0,-100 0,-94 6,-88 12,-88 12,-88 142,-88 142,-88 148,-88 154,-94 154,-100 154,-100 154,-112 154,-112 154,-118 148,-124 142,-124"/>
# <text text-anchor="middle" x="77" y="-108.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">I like the idea of living in Japan for a month.</text>
# <text text-anchor="middle" x="77" y="-100.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">(sentence)</text>
# </g>
# <!-- (0, &#39;token&#39;, 1) -->
# <g id="node3" class="node">
# <title>(0, &#39;token&#39;, 1)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M233,-124C233,-124 203,-124 203,-124 197,-124 191,-118 191,-112 191,-112 191,-100 191,-100 191,-94 197,-88 203,-88 203,-88 233,-88 233,-88 239,-88 245,-94 245,-100 245,-100 245,-112 245,-112 245,-118 239,-124 233,-124"/>
# <text text-anchor="middle" x="218" y="-108.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">[1] &#39;like&#39;</text>
# <text text-anchor="middle" x="218" y="-100.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">verb</text>
# </g>
# <!-- (0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 1) -->
# <g id="edge1" class="edge">
# <title>(0, &#39;sentence&#39;, 0, 12)&#45;&gt;(0, &#39;token&#39;, 1)</title>
# <path fill="none" stroke="#959595" d="M154.01,-106C165.24,-106 176.24,-106 185.83,-106"/>
# <polygon fill="#959595" stroke="#959595" points="186,-107.75 191,-106 186,-104.25 186,-107.75"/>
# </g>
# <!-- (0, &#39;token&#39;, 0) -->
# <g id="node2" class="node">
# <title>(0, &#39;token&#39;, 0)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M365,-178C365,-178 335,-178 335,-178 329,-178 323,-172 323,-166 323,-166 323,-154 323,-154 323,-148 329,-142 335,-142 335,-142 365,-142 365,-142 371,-142 377,-148 377,-154 377,-154 377,-166 377,-166 377,-172 371,-178 365,-178"/>
# <text text-anchor="middle" x="350" y="-162.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">[0] &#39;I&#39;</text>
# <text text-anchor="middle" x="350" y="-154.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">pronoun</text>
# </g>
# <!-- (0, &#39;token&#39;, 1)&#45;&gt;(0, &#39;token&#39;, 0) -->
# <g id="edge2" class="edge">
# <title>(0, &#39;token&#39;, 1)&#45;&gt;(0, &#39;token&#39;, 0)</title>
# <path fill="none" stroke="#959595" d="M245.31,-119.73C251.08,-122.58 257.2,-125.48 263,-128 280.88,-135.77 301.31,-143.42 317.77,-149.29"/>
# <polygon fill="#959595" stroke="#959595" points="317.45,-151.03 322.74,-151.06 318.62,-147.74 317.45,-151.03"/>
# <text text-anchor="middle" x="284" y="-155.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#959595">nominal</text>
# <text text-anchor="middle" x="284" y="-146.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#959595">subject</text>
# </g>
# <!-- (0, &#39;token&#39;, 3) -->
# <g id="node5" class="node">
# <title>(0, &#39;token&#39;, 3)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M365,-124C365,-124 335,-124 335,-124 329,-124 323,-118 323,-112 323,-112 323,-100 323,-100 323,-94 329,-88 335,-88 335,-88 365,-88 365,-88 371,-88 377,-94 377,-100 377,-100 377,-112 377,-112 377,-118 371,-124 365,-124"/>
# <text text-anchor="middle" x="350" y="-108.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">[3] &#39;idea&#39;</text>
# <text text-anchor="middle" x="350" y="-100.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">noun</text>
# </g>
# <!-- (0, &#39;token&#39;, 1)&#45;&gt;(0, &#39;token&#39;, 3) -->
# <g id="edge3" class="edge">
# <title>(0, &#39;token&#39;, 1)&#45;&gt;(0, &#39;token&#39;, 3)</title>
# <path fill="none" stroke="#959595" d="M245.31,-106C266.19,-106 295.44,-106 317.56,-106"/>
# <polygon fill="#959595" stroke="#959595" points="317.73,-107.75 322.73,-106 317.73,-104.25 317.73,-107.75"/>
# <text text-anchor="middle" x="284" y="-117.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#959595">direct</text>
# <text text-anchor="middle" x="284" y="-108.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#959595">object</text>
# </g>
# <!-- (0, &#39;token&#39;, 11) -->
# <g id="node13" class="node">
# <title>(0, &#39;token&#39;, 11)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M365,-70C365,-70 335,-70 335,-70 329,-70 323,-64 323,-58 323,-58 323,-46 323,-46 323,-40 329,-34 335,-34 335,-34 365,-34 365,-34 371,-34 377,-40 377,-46 377,-46 377,-58 377,-58 377,-64 371,-70 365,-70"/>
# <text text-anchor="middle" x="350" y="-54.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">[11] &#39;.&#39;</text>
# <text text-anchor="middle" x="350" y="-46.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">punctuation</text>
# </g>
# <!-- (0, &#39;token&#39;, 1)&#45;&gt;(0, &#39;token&#39;, 11) -->
# <g id="edge4" class="edge">
# <title>(0, &#39;token&#39;, 1)&#45;&gt;(0, &#39;token&#39;, 11)</title>
# <path fill="none" stroke="#959595" d="M245.31,-95.07C266.28,-86.36 295.69,-74.14 317.84,-64.94"/>
# <polygon fill="#959595" stroke="#959595" points="318.79,-66.45 322.73,-62.91 317.44,-63.21 318.79,-66.45"/>
# <text text-anchor="middle" x="284" y="-88.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#959595">punctuation</text>
# </g>
# <!-- (0, &#39;token&#39;, 2) -->
# <g id="node4" class="node">
# <title>(0, &#39;token&#39;, 2)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M501,-147C501,-147 471,-147 471,-147 465,-147 459,-141 459,-135 459,-135 459,-123 459,-123 459,-117 465,-111 471,-111 471,-111 501,-111 501,-111 507,-111 513,-117 513,-123 513,-123 513,-135 513,-135 513,-141 507,-147 501,-147"/>
# <text text-anchor="middle" x="486" y="-131.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">[2] &#39;the&#39;</text>
# <text text-anchor="middle" x="486" y="-123.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">determiner</text>
# </g>
# <!-- (0, &#39;token&#39;, 3)&#45;&gt;(0, &#39;token&#39;, 2) -->
# <g id="edge5" class="edge">
# <title>(0, &#39;token&#39;, 3)&#45;&gt;(0, &#39;token&#39;, 2)</title>
# <path fill="none" stroke="#959595" d="M377.15,-110.49C399.11,-114.26 430.52,-119.65 453.78,-123.64"/>
# <polygon fill="#959595" stroke="#959595" points="453.69,-125.4 458.91,-124.52 454.28,-121.95 453.69,-125.4"/>
# <text text-anchor="middle" x="418" y="-122.6" font-family="Helvetica,sans-Serif" font-size="8.00" fill="#959595">determiner</text>
# </g>
# <!-- (0, &#39;token&#39;, 4) -->
# <g id="node6" class="node">
# <title>(0, &#39;token&#39;, 4)</title>
# <path fill="#d4d4d4" stroke="#878787" d="M501,-93C501,-93 471,-93 471,-93 465,-93 459,-87 459,-81 459,-81 459,-69 459,-69 459,-63 465,-57 471,-57 471,-57 501,-57 501,-57 507,-57 513,-63 513,-69 513,-69 513,-81 513,-81 513,-87 507,-93 501,-93"/>
# <text text-anchor="middle" x="486" y="-77.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">[4] &#39;of&#39;</text>
# <text text-anchor="middle" x="486" y="-69.4" font-family="Helvetica,sans-Serif" font-size="7.00" fill="#000000">adposition</text>
